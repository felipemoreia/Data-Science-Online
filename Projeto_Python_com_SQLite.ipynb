# %% [markdown]
# <a href="https://colab.research.google.com/github/felipemoreia/Data-Science-Online/blob/master/Projeto_Python_com_SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Awari - Data Science
#
# ## Projeto - Python com SQLite
#
# ## 1. Considerações iniciais
#
# Para que você assimile melhor os comandos do SQL, preparamos este projeto de Python com SQLite. Neste notebook Jupyter, você irá reforçando alguns conceitos da unidade atual e deverá executar algumas tarefas pelo caminho. Todo o projeto deve ser executado neste Jupyter Notebook. Por fim, se desejar, revise as respostas com o seu mentor.
#
# ### 1.1. Por que SQLite?
# O SQLite é uma pequena biblioteca em C que possui um banco de dados SQL embutido. Sem o apoio de um poderoso SGDB (Sistema de Gerenciamento de Banco de Dados) como nas soluções do mercado, o SQLite é ideal para fins de aprendizagem, pois sua instalação é fácil e não requer nenhuma configuração inicial. Deste modo, podemos focar nos comandos do SQL.
#
# ### 1.2. Prepare seu ambiente
# Baixe e instale o SQLite antes de começar. Resumidamente, você irá acessar a página de [Downloads](https://www.sqlite.org/download.html) do SQLite e baixar os executáveis para a mesma pasta deste notebook. Caso você encontre dificuldades:
#
# - Assista a este [vídeo](https://www.youtube.com/watch?v=VcKKt6OTlJc) para "instalar" o SQLite no Windows ou;
# - Ou siga este [manual](http://www.devfuria.com.br/linux/instalando-sqlite/) para as plataformas Linux.
#
# ### 1.3. Conjunto de dados
#
# O conjunto de dados que iremos utilizar é derivado do [Titanic](https://www.kaggle.com/c/titanic/data). Na verdade, dividimos o conjunto em dois arquivos CSV - [passageiros](passageiros.csv) e [passagens](passagens.csv). Cada um destes arquivo serão inseridos dentro do SQLite como tabelas, onde você executará suas consultas SQL.
#
# #### 1.3.1. Descrição do dados
#
# No arquivo [passageiros](passageiros.csv), você encontrará:
# - PassengerId: Id do passageiro
# - Survived: Se o passageiro sobreviveu ou não. Se 0, então não sobreviveu. Se 1, sobreviveu.
# - Pclass: Classe em que o passageiro estava viajando. Se 1, então estava na primeira classe e assim por diante.
# - Name: Nome do passageiro.
# - Sex: Gênero do passageiro. Masculino ou feminino.
# - Age: Idade.
# - Sibsp: número de irmãos / esposas a bordo do navio.
# - Parch: número de pais / filhos a bordo do navio.
#
# E no arquivo [passagens](passagens.csv):
# - PassengerId: Id do passageiro
# - Ticket: número do ticket de embarque
# - Fare: valor pago pelo ticket.
# - Cabin: cabine do passageiro.
# - Embarked: porto de embarque do passageiro. C = Cherbourg, Q = Queenstown e S = Southampton

# %% [markdown]
# ## 2. Procedimentos
#
# ### 2.1. Leitura dos arquivos CSV
# Antes de importarmos os dados dentro das tabelas, precisamos começar lendo os arquivos CSV. O pequeno código abaixo importa os dados do CSV em uma lista de dicionários em Python.

# %%
import csv 

def importar_csv(arquivo):
    dados = []
    with open(arquivo) as arq:
        leitor = csv.DictReader(arq)
        for l in leitor:
            dados.append(dict(l))
    
    print('O conjunto de dados tem %s registros.' % len(dados))
    
    return dados

# %% [markdown]
# ### TAREFA 01
#
# 1. Importe o arquivo passagens.csv usando o mesmo código anterior.
#
# **DICA**: Não reinvente a roda, reutilize a função anterior.

# %%
passagens = importar_csv('passagens.csv')
passagens
# Out:
# O conjunto de dados tem 891 registros.
# [{'PassengerId': '1',
#   'Ticket': 'A/5 21171',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '2',
#   'Ticket': 'PC 17599',
#   'Fare': '71.2833',
#   'Cabin': 'C85',
#   'Embarked': 'C'},
#  {'PassengerId': '3',
#   'Ticket': 'STON/O2. 3101282',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '4',
#   'Ticket': '113803',
#   'Fare': '53.1',
#   'Cabin': 'C123',
#   'Embarked': 'S'},
#  {'PassengerId': '5',
#   'Ticket': '373450',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '6',
#   'Ticket': '330877',
#   'Fare': '8.4583',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '7',
#   'Ticket': '17463',
#   'Fare': '51.8625',
#   'Cabin': 'E46',
#   'Embarked': 'S'},
#  {'PassengerId': '8',
#   'Ticket': '349909',
#   'Fare': '21075',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '9',
#   'Ticket': '347742',
#   'Fare': '11.1333',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '10',
#   'Ticket': '237736',
#   'Fare': '30.0708',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '11',
#   'Ticket': 'PP 9549',
#   'Fare': '16.7',
#   'Cabin': 'G6',
#   'Embarked': 'S'},
#  {'PassengerId': '12',
#   'Ticket': '113783',
#   'Fare': '26.55',
#   'Cabin': 'C103',
#   'Embarked': 'S'},
#  {'PassengerId': '13',
#   'Ticket': 'A/5. 2151',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '14',
#   'Ticket': '347082',
#   'Fare': '31275',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '15',
#   'Ticket': '350406',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '16',
#   'Ticket': '248706',
#   'Fare': '16',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '17',
#   'Ticket': '382652',
#   'Fare': '29125',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '18',
#   'Ticket': '244373',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '19',
#   'Ticket': '345763',
#   'Fare': '18',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '20',
#   'Ticket': '2649',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '21',
#   'Ticket': '239865',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '22',
#   'Ticket': '248698',
#   'Fare': '13',
#   'Cabin': 'D56',
#   'Embarked': 'S'},
#  {'PassengerId': '23',
#   'Ticket': '330923',
#   'Fare': '8.0292',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '24',
#   'Ticket': '113788',
#   'Fare': '35.5',
#   'Cabin': 'A6',
#   'Embarked': 'S'},
#  {'PassengerId': '25',
#   'Ticket': '349909',
#   'Fare': '21075',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '26',
#   'Ticket': '347077',
#   'Fare': '31.3875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '27',
#   'Ticket': '2631',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '28',
#   'Ticket': '19950',
#   'Fare': '263',
#   'Cabin': 'C23 C25 C27',
#   'Embarked': 'S'},
#  {'PassengerId': '29',
#   'Ticket': '330959',
#   'Fare': '7.8792',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '30',
#   'Ticket': '349216',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '31',
#   'Ticket': 'PC 17601',
#   'Fare': '27.7208',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '32',
#   'Ticket': 'PC 17569',
#   'Fare': '146.5208',
#   'Cabin': 'B78',
#   'Embarked': 'C'},
#  {'PassengerId': '33',
#   'Ticket': '335677',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '34',
#   'Ticket': 'C.A. 24579',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '35',
#   'Ticket': 'PC 17604',
#   'Fare': '82.1708',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '36',
#   'Ticket': '113789',
#   'Fare': '52',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '37',
#   'Ticket': '2677',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '38',
#   'Ticket': 'A./5. 2152',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '39',
#   'Ticket': '345764',
#   'Fare': '18',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '40',
#   'Ticket': '2651',
#   'Fare': '11.2417',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '41',
#   'Ticket': '7546',
#   'Fare': '9475',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '42',
#   'Ticket': '11668',
#   'Fare': '21',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '43',
#   'Ticket': '349253',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '44',
#   'Ticket': 'SC/Paris 2123',
#   'Fare': '41.5792',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '45',
#   'Ticket': '330958',
#   'Fare': '7.8792',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '46',
#   'Ticket': 'S.C./A.4. 23567',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '47',
#   'Ticket': '370371',
#   'Fare': '15.5',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '48',
#   'Ticket': '14311',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '49',
#   'Ticket': '2662',
#   'Fare': '21.6792',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '50',
#   'Ticket': '349237',
#   'Fare': '17.8',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '51',
#   'Ticket': '3101295',
#   'Fare': '39.6875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '52',
#   'Ticket': 'A/4. 39886',
#   'Fare': '7.8',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '53',
#   'Ticket': 'PC 17572',
#   'Fare': '76.7292',
#   'Cabin': 'D33',
#   'Embarked': 'C'},
#  {'PassengerId': '54',
#   'Ticket': '2926',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '55',
#   'Ticket': '113509',
#   'Fare': '61.9792',
#   'Cabin': 'B30',
#   'Embarked': 'C'},
#  {'PassengerId': '56',
#   'Ticket': '19947',
#   'Fare': '35.5',
#   'Cabin': 'C52',
#   'Embarked': 'S'},
#  {'PassengerId': '57',
#   'Ticket': 'C.A. 31026',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '58',
#   'Ticket': '2697',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '59',
#   'Ticket': 'C.A. 34651',
#   'Fare': '27.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '60',
#   'Ticket': 'CA 2144',
#   'Fare': '46.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '61',
#   'Ticket': '2669',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '62',
#   'Ticket': '113572',
#   'Fare': '80',
#   'Cabin': 'B28',
#   'Embarked': ''},
#  {'PassengerId': '63',
#   'Ticket': '36973',
#   'Fare': '83475',
#   'Cabin': 'C83',
#   'Embarked': 'S'},
#  {'PassengerId': '64',
#   'Ticket': '347088',
#   'Fare': '27.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '65',
#   'Ticket': 'PC 17605',
#   'Fare': '27.7208',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '66',
#   'Ticket': '2661',
#   'Fare': '15.2458',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '67',
#   'Ticket': 'C.A. 29395',
#   'Fare': '10.5',
#   'Cabin': 'F33',
#   'Embarked': 'S'},
#  {'PassengerId': '68',
#   'Ticket': 'S.P. 3464',
#   'Fare': '8.1583',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '69',
#   'Ticket': '3101281',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '70',
#   'Ticket': '315151',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '71',
#   'Ticket': 'C.A. 33111',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '72',
#   'Ticket': 'CA 2144',
#   'Fare': '46.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '73',
#   'Ticket': 'S.O.C. 14879',
#   'Fare': '73.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '74',
#   'Ticket': '2680',
#   'Fare': '14.4542',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '75',
#   'Ticket': '1601',
#   'Fare': '56.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '76',
#   'Ticket': '348123',
#   'Fare': '7.65',
#   'Cabin': 'F G73',
#   'Embarked': 'S'},
#  {'PassengerId': '77',
#   'Ticket': '349208',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '78',
#   'Ticket': '374746',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '79',
#   'Ticket': '248738',
#   'Fare': '29',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '80',
#   'Ticket': '364516',
#   'Fare': '12475',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '81',
#   'Ticket': '345767',
#   'Fare': '9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '82',
#   'Ticket': '345779',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '83',
#   'Ticket': '330932',
#   'Fare': '7.7875',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '84',
#   'Ticket': '113059',
#   'Fare': '47.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '85',
#   'Ticket': 'SO/C 14885',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '86',
#   'Ticket': '3101278',
#   'Fare': '15.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '87',
#   'Ticket': 'W./C. 6608',
#   'Fare': '34375',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '88',
#   'Ticket': 'SOTON/OQ 392086',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '89',
#   'Ticket': '19950',
#   'Fare': '263',
#   'Cabin': 'C23 C25 C27',
#   'Embarked': 'S'},
#  {'PassengerId': '90',
#   'Ticket': '343275',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '91',
#   'Ticket': '343276',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '92',
#   'Ticket': '347466',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '93',
#   'Ticket': 'W.E.P. 5734',
#   'Fare': '61175',
#   'Cabin': 'E31',
#   'Embarked': 'S'},
#  {'PassengerId': '94',
#   'Ticket': 'C.A. 2315',
#   'Fare': '20575',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '95',
#   'Ticket': '364500',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '96',
#   'Ticket': '374910',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '97',
#   'Ticket': 'PC 17754',
#   'Fare': '34.6542',
#   'Cabin': 'A5',
#   'Embarked': 'C'},
#  {'PassengerId': '98',
#   'Ticket': 'PC 17759',
#   'Fare': '63.3583',
#   'Cabin': 'D10 D12',
#   'Embarked': 'C'},
#  {'PassengerId': '99',
#   'Ticket': '231919',
#   'Fare': '23',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '100',
#   'Ticket': '244367',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '101',
#   'Ticket': '349245',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '102',
#   'Ticket': '349215',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '103',
#   'Ticket': '35281',
#   'Fare': '77.2875',
#   'Cabin': 'D26',
#   'Embarked': 'S'},
#  {'PassengerId': '104',
#   'Ticket': '7540',
#   'Fare': '8.6542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '105',
#   'Ticket': '3101276',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '106',
#   'Ticket': '349207',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '107',
#   'Ticket': '343120',
#   'Fare': '7.65',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '108',
#   'Ticket': '312991',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '109',
#   'Ticket': '349249',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '110',
#   'Ticket': '371110',
#   'Fare': '24.15',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '111',
#   'Ticket': '110465',
#   'Fare': '52',
#   'Cabin': 'C110',
#   'Embarked': 'S'},
#  {'PassengerId': '112',
#   'Ticket': '2665',
#   'Fare': '14.4542',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '113',
#   'Ticket': '324669',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '114',
#   'Ticket': '4136',
#   'Fare': '9825',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '115',
#   'Ticket': '2627',
#   'Fare': '14.4583',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '116',
#   'Ticket': 'STON/O 2. 3101294',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '117',
#   'Ticket': '370369',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '118',
#   'Ticket': '11668',
#   'Fare': '21',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '119',
#   'Ticket': 'PC 17558',
#   'Fare': '247.5208',
#   'Cabin': 'B58 B60',
#   'Embarked': 'C'},
#  {'PassengerId': '120',
#   'Ticket': '347082',
#   'Fare': '31275',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '121',
#   'Ticket': 'S.O.C. 14879',
#   'Fare': '73.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '122',
#   'Ticket': 'A4. 54510',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '123',
#   'Ticket': '237736',
#   'Fare': '30.0708',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '124',
#   'Ticket': '27267',
#   'Fare': '13',
#   'Cabin': 'E101',
#   'Embarked': 'S'},
#  {'PassengerId': '125',
#   'Ticket': '35281',
#   'Fare': '77.2875',
#   'Cabin': 'D26',
#   'Embarked': 'S'},
#  {'PassengerId': '126',
#   'Ticket': '2651',
#   'Fare': '11.2417',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '127',
#   'Ticket': '370372',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '128',
#   'Ticket': 'C 17369',
#   'Fare': '7.1417',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '129',
#   'Ticket': '2668',
#   'Fare': '22.3583',
#   'Cabin': 'F E69',
#   'Embarked': 'C'},
#  {'PassengerId': '130',
#   'Ticket': '347061',
#   'Fare': '6975',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '131',
#   'Ticket': '349241',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '132',
#   'Ticket': 'SOTON/O.Q. 3101307',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '133',
#   'Ticket': 'A/5. 3337',
#   'Fare': '14.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '134',
#   'Ticket': '228414',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '135',
#   'Ticket': 'C.A. 29178',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '136',
#   'Ticket': 'SC/PARIS 2133',
#   'Fare': '15.0458',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '137',
#   'Ticket': '11752',
#   'Fare': '26.2833',
#   'Cabin': 'D47',
#   'Embarked': 'S'},
#  {'PassengerId': '138',
#   'Ticket': '113803',
#   'Fare': '53.1',
#   'Cabin': 'C123',
#   'Embarked': 'S'},
#  {'PassengerId': '139',
#   'Ticket': '7534',
#   'Fare': '9.2167',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '140',
#   'Ticket': 'PC 17593',
#   'Fare': '79.2',
#   'Cabin': 'B86',
#   'Embarked': 'C'},
#  {'PassengerId': '141',
#   'Ticket': '2678',
#   'Fare': '15.2458',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '142',
#   'Ticket': '347081',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '143',
#   'Ticket': 'STON/O2. 3101279',
#   'Fare': '15.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '144',
#   'Ticket': '365222',
#   'Fare': '6.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '145',
#   'Ticket': '231945',
#   'Fare': '11.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '146',
#   'Ticket': 'C.A. 33112',
#   'Fare': '36.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '147',
#   'Ticket': '350043',
#   'Fare': '7.7958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '148',
#   'Ticket': 'W./C. 6608',
#   'Fare': '34375',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '149',
#   'Ticket': '230080',
#   'Fare': '26',
#   'Cabin': 'F2',
#   'Embarked': 'S'},
#  {'PassengerId': '150',
#   'Ticket': '244310',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '151',
#   'Ticket': 'S.O.P. 1166',
#   'Fare': '12525',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '152',
#   'Ticket': '113776',
#   'Fare': '66.6',
#   'Cabin': 'C2',
#   'Embarked': 'S'},
#  {'PassengerId': '153',
#   'Ticket': 'A.5. 11206',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '154',
#   'Ticket': 'A/5. 851',
#   'Fare': '14.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '155',
#   'Ticket': 'Fa 265302',
#   'Fare': '7.3125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '156',
#   'Ticket': 'PC 17597',
#   'Fare': '61.3792',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '157',
#   'Ticket': '35851',
#   'Fare': '7.7333',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '158',
#   'Ticket': 'SOTON/OQ 392090',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '159',
#   'Ticket': '315037',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '160',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '161',
#   'Ticket': '371362',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '162',
#   'Ticket': 'C.A. 33595',
#   'Fare': '15.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '163',
#   'Ticket': '347068',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '164',
#   'Ticket': '315093',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '165',
#   'Ticket': '3101295',
#   'Fare': '39.6875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '166',
#   'Ticket': '363291',
#   'Fare': '20525',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '167',
#   'Ticket': '113505',
#   'Fare': '55',
#   'Cabin': 'E33',
#   'Embarked': 'S'},
#  {'PassengerId': '168',
#   'Ticket': '347088',
#   'Fare': '27.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '169',
#   'Ticket': 'PC 17318',
#   'Fare': '25925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '170',
#   'Ticket': '1601',
#   'Fare': '56.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '171',
#   'Ticket': '111240',
#   'Fare': '33.5',
#   'Cabin': 'B19',
#   'Embarked': 'S'},
#  {'PassengerId': '172',
#   'Ticket': '382652',
#   'Fare': '29125',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '173',
#   'Ticket': '347742',
#   'Fare': '11.1333',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '174',
#   'Ticket': 'STON/O 2. 3101280',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '175',
#   'Ticket': '17764',
#   'Fare': '30.6958',
#   'Cabin': 'A7',
#   'Embarked': 'C'},
#  {'PassengerId': '176',
#   'Ticket': '350404',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '177',
#   'Ticket': '4133',
#   'Fare': '25.4667',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '178',
#   'Ticket': 'PC 17595',
#   'Fare': '28.7125',
#   'Cabin': 'C49',
#   'Embarked': 'C'},
#  {'PassengerId': '179',
#   'Ticket': '250653',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '180',
#   'Ticket': 'LINE',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '181',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '182',
#   'Ticket': 'SC/PARIS 2131',
#   'Fare': '15.05',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '183',
#   'Ticket': '347077',
#   'Fare': '31.3875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '184',
#   'Ticket': '230136',
#   'Fare': '39',
#   'Cabin': 'F4',
#   'Embarked': 'S'},
#  {'PassengerId': '185',
#   'Ticket': '315153',
#   'Fare': '22025',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '186',
#   'Ticket': '113767',
#   'Fare': '50',
#   'Cabin': 'A32',
#   'Embarked': 'S'},
#  {'PassengerId': '187',
#   'Ticket': '370365',
#   'Fare': '15.5',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '188',
#   'Ticket': '111428',
#   'Fare': '26.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '189',
#   'Ticket': '364849',
#   'Fare': '15.5',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '190',
#   'Ticket': '349247',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '191',
#   'Ticket': '234604',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '192',
#   'Ticket': '28424',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '193',
#   'Ticket': '350046',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '194',
#   'Ticket': '230080',
#   'Fare': '26',
#   'Cabin': 'F2',
#   'Embarked': 'S'},
#  {'PassengerId': '195',
#   'Ticket': 'PC 17610',
#   'Fare': '27.7208',
#   'Cabin': 'B4',
#   'Embarked': 'C'},
#  {'PassengerId': '196',
#   'Ticket': 'PC 17569',
#   'Fare': '146.5208',
#   'Cabin': 'B80',
#   'Embarked': 'C'},
#  {'PassengerId': '197',
#   'Ticket': '368703',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '198',
#   'Ticket': '4579',
#   'Fare': '8.4042',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '199',
#   'Ticket': '370370',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '200',
#   'Ticket': '248747',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '201',
#   'Ticket': '345770',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '202',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '203',
#   'Ticket': '3101264',
#   'Fare': '6.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '204',
#   'Ticket': '2628',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '205',
#   'Ticket': 'A/5 3540',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '206',
#   'Ticket': '347054',
#   'Fare': '10.4625',
#   'Cabin': 'G6',
#   'Embarked': 'S'},
#  {'PassengerId': '207',
#   'Ticket': '3101278',
#   'Fare': '15.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '208',
#   'Ticket': '2699',
#   'Fare': '18.7875',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '209',
#   'Ticket': '367231',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '210',
#   'Ticket': '112277',
#   'Fare': '31',
#   'Cabin': 'A31',
#   'Embarked': 'C'},
#  {'PassengerId': '211',
#   'Ticket': 'SOTON/O.Q. 3101311',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '212',
#   'Ticket': 'F.C.C. 13528',
#   'Fare': '21',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '213',
#   'Ticket': 'A/5 21174',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '214',
#   'Ticket': '250646',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '215',
#   'Ticket': '367229',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '216',
#   'Ticket': '35273',
#   'Fare': '113275',
#   'Cabin': 'D36',
#   'Embarked': 'C'},
#  {'PassengerId': '217',
#   'Ticket': 'STON/O2. 3101283',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '218',
#   'Ticket': '243847',
#   'Fare': '27',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '219',
#   'Ticket': '11813',
#   'Fare': '76.2917',
#   'Cabin': 'D15',
#   'Embarked': 'C'},
#  {'PassengerId': '220',
#   'Ticket': 'W/C 14208',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '221',
#   'Ticket': 'SOTON/OQ 392089',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '222',
#   'Ticket': '220367',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '223',
#   'Ticket': '21440',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '224',
#   'Ticket': '349234',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '225',
#   'Ticket': '19943',
#   'Fare': '90',
#   'Cabin': 'C93',
#   'Embarked': 'S'},
#  {'PassengerId': '226',
#   'Ticket': 'PP 4348',
#   'Fare': '9.35',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '227',
#   'Ticket': 'SW/PP 751',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '228',
#   'Ticket': 'A/5 21173',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '229',
#   'Ticket': '236171',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '230',
#   'Ticket': '4133',
#   'Fare': '25.4667',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '231',
#   'Ticket': '36973',
#   'Fare': '83475',
#   'Cabin': 'C83',
#   'Embarked': 'S'},
#  {'PassengerId': '232',
#   'Ticket': '347067',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '233',
#   'Ticket': '237442',
#   'Fare': '13.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '234',
#   'Ticket': '347077',
#   'Fare': '31.3875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '235',
#   'Ticket': 'C.A. 29566',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '236',
#   'Ticket': 'W./C. 6609',
#   'Fare': '7.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '237',
#   'Ticket': '26707',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '238',
#   'Ticket': 'C.A. 31921',
#   'Fare': '26.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '239',
#   'Ticket': '28665',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '240',
#   'Ticket': 'SCO/W 1585',
#   'Fare': '12275',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '241',
#   'Ticket': '2665',
#   'Fare': '14.4542',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '242',
#   'Ticket': '367230',
#   'Fare': '15.5',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '243',
#   'Ticket': 'W./C. 14263',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '244',
#   'Ticket': 'STON/O 2. 3101275',
#   'Fare': '7125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '245',
#   'Ticket': '2694',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '246',
#   'Ticket': '19928',
#   'Fare': '90',
#   'Cabin': 'C78',
#   'Embarked': 'Q'},
#  {'PassengerId': '247',
#   'Ticket': '347071',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '248',
#   'Ticket': '250649',
#   'Fare': '14.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '249',
#   'Ticket': '11751',
#   'Fare': '52.5542',
#   'Cabin': 'D35',
#   'Embarked': 'S'},
#  {'PassengerId': '250',
#   'Ticket': '244252',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '251',
#   'Ticket': '362316',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '252',
#   'Ticket': '347054',
#   'Fare': '10.4625',
#   'Cabin': 'G6',
#   'Embarked': 'S'},
#  {'PassengerId': '253',
#   'Ticket': '113514',
#   'Fare': '26.55',
#   'Cabin': 'C87',
#   'Embarked': 'S'},
#  {'PassengerId': '254',
#   'Ticket': 'A/5. 3336',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '255',
#   'Ticket': '370129',
#   'Fare': '20.2125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '256',
#   'Ticket': '2650',
#   'Fare': '15.2458',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '257',
#   'Ticket': 'PC 17585',
#   'Fare': '79.2',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '258',
#   'Ticket': '110152',
#   'Fare': '86.5',
#   'Cabin': 'B77',
#   'Embarked': 'S'},
#  {'PassengerId': '259',
#   'Ticket': 'PC 17755',
#   'Fare': '512.3292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '260',
#   'Ticket': '230433',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '261',
#   'Ticket': '384461',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '262',
#   'Ticket': '347077',
#   'Fare': '31.3875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '263',
#   'Ticket': '110413',
#   'Fare': '79.65',
#   'Cabin': 'E67',
#   'Embarked': 'S'},
#  {'PassengerId': '264',
#   'Ticket': '112059',
#   'Fare': '0',
#   'Cabin': 'B94',
#   'Embarked': 'S'},
#  {'PassengerId': '265',
#   'Ticket': '382649',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '266',
#   'Ticket': 'C.A. 17248',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '267',
#   'Ticket': '3101295',
#   'Fare': '39.6875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '268',
#   'Ticket': '347083',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '269',
#   'Ticket': 'PC 17582',
#   'Fare': '153.4625',
#   'Cabin': 'C125',
#   'Embarked': 'S'},
#  {'PassengerId': '270',
#   'Ticket': 'PC 17760',
#   'Fare': '135.6333',
#   'Cabin': 'C99',
#   'Embarked': 'S'},
#  {'PassengerId': '271',
#   'Ticket': '113798',
#   'Fare': '31',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '272',
#   'Ticket': 'LINE',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '273',
#   'Ticket': '250644',
#   'Fare': '19.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '274',
#   'Ticket': 'PC 17596',
#   'Fare': '29.7',
#   'Cabin': 'C118',
#   'Embarked': 'C'},
#  {'PassengerId': '275',
#   'Ticket': '370375',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '276',
#   'Ticket': '13502',
#   'Fare': '77.9583',
#   'Cabin': 'D7',
#   'Embarked': 'S'},
#  {'PassengerId': '277',
#   'Ticket': '347073',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '278',
#   'Ticket': '239853',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '279',
#   'Ticket': '382652',
#   'Fare': '29125',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '280',
#   'Ticket': 'C.A. 2673',
#   'Fare': '20.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '281',
#   'Ticket': '336439',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '282',
#   'Ticket': '347464',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '283',
#   'Ticket': '345778',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '284',
#   'Ticket': 'A/5. 10482',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '285',
#   'Ticket': '113056',
#   'Fare': '26',
#   'Cabin': 'A19',
#   'Embarked': 'S'},
#  {'PassengerId': '286',
#   'Ticket': '349239',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '287',
#   'Ticket': '345774',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '288',
#   'Ticket': '349206',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '289',
#   'Ticket': '237798',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '290',
#   'Ticket': '370373',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '291',
#   'Ticket': '19877',
#   'Fare': '78.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '292',
#   'Ticket': '11967',
#   'Fare': '91.0792',
#   'Cabin': 'B49',
#   'Embarked': 'C'},
#  {'PassengerId': '293',
#   'Ticket': 'SC/Paris 2163',
#   'Fare': '12875',
#   'Cabin': 'D',
#   'Embarked': 'C'},
#  {'PassengerId': '294',
#   'Ticket': '349236',
#   'Fare': '8.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '295',
#   'Ticket': '349233',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '296',
#   'Ticket': 'PC 17612',
#   'Fare': '27.7208',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '297',
#   'Ticket': '2693',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '298',
#   'Ticket': '113781',
#   'Fare': '151.55',
#   'Cabin': 'C22 C26',
#   'Embarked': 'S'},
#  {'PassengerId': '299',
#   'Ticket': '19988',
#   'Fare': '30.5',
#   'Cabin': 'C106',
#   'Embarked': 'S'},
#  {'PassengerId': '300',
#   'Ticket': 'PC 17558',
#   'Fare': '247.5208',
#   'Cabin': 'B58 B60',
#   'Embarked': 'C'},
#  {'PassengerId': '301',
#   'Ticket': '9234',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '302',
#   'Ticket': '367226',
#   'Fare': '23.25',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '303',
#   'Ticket': 'LINE',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '304',
#   'Ticket': '226593',
#   'Fare': '12.35',
#   'Cabin': 'E101',
#   'Embarked': 'Q'},
#  {'PassengerId': '305',
#   'Ticket': 'A/5 2466',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '306',
#   'Ticket': '113781',
#   'Fare': '151.55',
#   'Cabin': 'C22 C26',
#   'Embarked': 'S'},
#  {'PassengerId': '307',
#   'Ticket': '17421',
#   'Fare': '110.8833',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '308',
#   'Ticket': 'PC 17758',
#   'Fare': '108.9',
#   'Cabin': 'C65',
#   'Embarked': 'C'},
#  {'PassengerId': '309',
#   'Ticket': 'P/PP 3381',
#   'Fare': '24',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '310',
#   'Ticket': 'PC 17485',
#   'Fare': '56.9292',
#   'Cabin': 'E36',
#   'Embarked': 'C'},
#  {'PassengerId': '311',
#   'Ticket': '11767',
#   'Fare': '83.1583',
#   'Cabin': 'C54',
#   'Embarked': 'C'},
#  {'PassengerId': '312',
#   'Ticket': 'PC 17608',
#   'Fare': '262375',
#   'Cabin': 'B57 B59 B63 B66',
#   'Embarked': 'C'},
#  {'PassengerId': '313',
#   'Ticket': '250651',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '314',
#   'Ticket': '349243',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '315',
#   'Ticket': 'F.C.C. 13529',
#   'Fare': '26.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '316',
#   'Ticket': '347470',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '317',
#   'Ticket': '244367',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '318',
#   'Ticket': '29011',
#   'Fare': '14',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '319',
#   'Ticket': '36928',
#   'Fare': '164.8667',
#   'Cabin': 'C7',
#   'Embarked': 'S'},
#  {'PassengerId': '320',
#   'Ticket': '16966',
#   'Fare': '134.5',
#   'Cabin': 'E34',
#   'Embarked': 'C'},
#  {'PassengerId': '321',
#   'Ticket': 'A/5 21172',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '322',
#   'Ticket': '349219',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '323',
#   'Ticket': '234818',
#   'Fare': '12.35',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '324',
#   'Ticket': '248738',
#   'Fare': '29',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '325',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '326',
#   'Ticket': 'PC 17760',
#   'Fare': '135.6333',
#   'Cabin': 'C32',
#   'Embarked': 'C'},
#  {'PassengerId': '327',
#   'Ticket': '345364',
#   'Fare': '6.2375',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '328',
#   'Ticket': '28551',
#   'Fare': '13',
#   'Cabin': 'D',
#   'Embarked': 'S'},
#  {'PassengerId': '329',
#   'Ticket': '363291',
#   'Fare': '20525',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '330',
#   'Ticket': '111361',
#   'Fare': '57.9792',
#   'Cabin': 'B18',
#   'Embarked': 'C'},
#  {'PassengerId': '331',
#   'Ticket': '367226',
#   'Fare': '23.25',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '332',
#   'Ticket': '113043',
#   'Fare': '28.5',
#   'Cabin': 'C124',
#   'Embarked': 'S'},
#  {'PassengerId': '333',
#   'Ticket': 'PC 17582',
#   'Fare': '153.4625',
#   'Cabin': 'C91',
#   'Embarked': 'S'},
#  {'PassengerId': '334',
#   'Ticket': '345764',
#   'Fare': '18',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '335',
#   'Ticket': 'PC 17611',
#   'Fare': '133.65',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '336',
#   'Ticket': '349225',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '337',
#   'Ticket': '113776',
#   'Fare': '66.6',
#   'Cabin': 'C2',
#   'Embarked': 'S'},
#  {'PassengerId': '338',
#   'Ticket': '16966',
#   'Fare': '134.5',
#   'Cabin': 'E40',
#   'Embarked': 'C'},
#  {'PassengerId': '339',
#   'Ticket': '7598',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '340',
#   'Ticket': '113784',
#   'Fare': '35.5',
#   'Cabin': 'T',
#   'Embarked': 'S'},
#  {'PassengerId': '341',
#   'Ticket': '230080',
#   'Fare': '26',
#   'Cabin': 'F2',
#   'Embarked': 'S'},
#  {'PassengerId': '342',
#   'Ticket': '19950',
#   'Fare': '263',
#   'Cabin': 'C23 C25 C27',
#   'Embarked': 'S'},
#  {'PassengerId': '343',
#   'Ticket': '248740',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '344',
#   'Ticket': '244361',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '345',
#   'Ticket': '229236',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '346',
#   'Ticket': '248733',
#   'Fare': '13',
#   'Cabin': 'F33',
#   'Embarked': 'S'},
#  {'PassengerId': '347',
#   'Ticket': '31418',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '348',
#   'Ticket': '386525',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '349',
#   'Ticket': 'C.A. 37671',
#   'Fare': '15.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '350',
#   'Ticket': '315088',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '351',
#   'Ticket': '7267',
#   'Fare': '9225',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '352',
#   'Ticket': '113510',
#   'Fare': '35',
#   'Cabin': 'C128',
#   'Embarked': 'S'},
#  {'PassengerId': '353',
#   'Ticket': '2695',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '354',
#   'Ticket': '349237',
#   'Fare': '17.8',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '355',
#   'Ticket': '2647',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '356',
#   'Ticket': '345783',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '357',
#   'Ticket': '113505',
#   'Fare': '55',
#   'Cabin': 'E33',
#   'Embarked': 'S'},
#  {'PassengerId': '358',
#   'Ticket': '237671',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '359',
#   'Ticket': '330931',
#   'Fare': '7.8792',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '360',
#   'Ticket': '330980',
#   'Fare': '7.8792',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '361',
#   'Ticket': '347088',
#   'Fare': '27.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '362',
#   'Ticket': 'SC/PARIS 2167',
#   'Fare': '27.7208',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '363',
#   'Ticket': '2691',
#   'Fare': '14.4542',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '364',
#   'Ticket': 'SOTON/O.Q. 3101310',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '365',
#   'Ticket': '370365',
#   'Fare': '15.5',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '366',
#   'Ticket': 'C 7076',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '367',
#   'Ticket': '110813',
#   'Fare': '75.25',
#   'Cabin': 'D37',
#   'Embarked': 'C'},
#  {'PassengerId': '368',
#   'Ticket': '2626',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '369',
#   'Ticket': '14313',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '370',
#   'Ticket': 'PC 17477',
#   'Fare': '69.3',
#   'Cabin': 'B35',
#   'Embarked': 'C'},
#  {'PassengerId': '371',
#   'Ticket': '11765',
#   'Fare': '55.4417',
#   'Cabin': 'E50',
#   'Embarked': 'C'},
#  {'PassengerId': '372',
#   'Ticket': '3101267',
#   'Fare': '6.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '373',
#   'Ticket': '323951',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '374',
#   'Ticket': 'PC 17760',
#   'Fare': '135.6333',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '375',
#   'Ticket': '349909',
#   'Fare': '21075',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '376',
#   'Ticket': 'PC 17604',
#   'Fare': '82.1708',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '377',
#   'Ticket': 'C 7077',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '378',
#   'Ticket': '113503',
#   'Fare': '211.5',
#   'Cabin': 'C82',
#   'Embarked': 'C'},
#  {'PassengerId': '379',
#   'Ticket': '2648',
#   'Fare': '4.0125',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '380',
#   'Ticket': '347069',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '381',
#   'Ticket': 'PC 17757',
#   'Fare': '227525',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '382',
#   'Ticket': '2653',
#   'Fare': '15.7417',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '383',
#   'Ticket': 'STON/O 2. 3101293',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '384',
#   'Ticket': '113789',
#   'Fare': '52',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '385',
#   'Ticket': '349227',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '386',
#   'Ticket': 'S.O.C. 14879',
#   'Fare': '73.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '387',
#   'Ticket': 'CA 2144',
#   'Fare': '46.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '388',
#   'Ticket': '27849',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '389',
#   'Ticket': '367655',
#   'Fare': '7.7292',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '390',
#   'Ticket': 'SC 1748',
#   'Fare': '12',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '391',
#   'Ticket': '113760',
#   'Fare': '120',
#   'Cabin': 'B96 B98',
#   'Embarked': 'S'},
#  {'PassengerId': '392',
#   'Ticket': '350034',
#   'Fare': '7.7958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '393',
#   'Ticket': '3101277',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '394',
#   'Ticket': '35273',
#   'Fare': '113275',
#   'Cabin': 'D36',
#   'Embarked': 'C'},
#  {'PassengerId': '395',
#   'Ticket': 'PP 9549',
#   'Fare': '16.7',
#   'Cabin': 'G6',
#   'Embarked': 'S'},
#  {'PassengerId': '396',
#   'Ticket': '350052',
#   'Fare': '7.7958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '397',
#   'Ticket': '350407',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '398',
#   'Ticket': '28403',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '399',
#   'Ticket': '244278',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '400',
#   'Ticket': '240929',
#   'Fare': '12.65',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '401',
#   'Ticket': 'STON/O 2. 3101289',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '402',
#   'Ticket': '341826',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '403',
#   'Ticket': '4137',
#   'Fare': '9825',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '404',
#   'Ticket': 'STON/O2. 3101279',
#   'Fare': '15.85',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '405',
#   'Ticket': '315096',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '406',
#   'Ticket': '28664',
#   'Fare': '21',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '407',
#   'Ticket': '347064',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '408',
#   'Ticket': '29106',
#   'Fare': '18.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '409',
#   'Ticket': '312992',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '410',
#   'Ticket': '4133',
#   'Fare': '25.4667',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '411',
#   'Ticket': '349222',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '412',
#   'Ticket': '394140',
#   'Fare': '6.8583',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '413',
#   'Ticket': '19928',
#   'Fare': '90',
#   'Cabin': 'C78',
#   'Embarked': 'Q'},
#  {'PassengerId': '414',
#   'Ticket': '239853',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '415',
#   'Ticket': 'STON/O 2. 3101269',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '416',
#   'Ticket': '343095',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '417',
#   'Ticket': '28220',
#   'Fare': '32.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '418',
#   'Ticket': '250652',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '419',
#   'Ticket': '28228',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '420',
#   'Ticket': '345773',
#   'Fare': '24.15',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '421',
#   'Ticket': '349254',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '422',
#   'Ticket': 'A/5. 13032',
#   'Fare': '7.7333',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '423',
#   'Ticket': '315082',
#   'Fare': '7875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '424',
#   'Ticket': '347080',
#   'Fare': '14.4',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '425',
#   'Ticket': '370129',
#   'Fare': '20.2125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '426',
#   'Ticket': 'A/4. 34244',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '427',
#   'Ticket': '2003',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '428',
#   'Ticket': '250655',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '429',
#   'Ticket': '364851',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '430',
#   'Ticket': 'SOTON/O.Q. 392078',
#   'Fare': '8.05',
#   'Cabin': 'E10',
#   'Embarked': 'S'},
#  {'PassengerId': '431',
#   'Ticket': '110564',
#   'Fare': '26.55',
#   'Cabin': 'C52',
#   'Embarked': 'S'},
#  {'PassengerId': '432',
#   'Ticket': '376564',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '433',
#   'Ticket': 'SC/AH 3085',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '434',
#   'Ticket': 'STON/O 2. 3101274',
#   'Fare': '7125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '435',
#   'Ticket': '13507',
#   'Fare': '55.9',
#   'Cabin': 'E44',
#   'Embarked': 'S'},
#  {'PassengerId': '436',
#   'Ticket': '113760',
#   'Fare': '120',
#   'Cabin': 'B96 B98',
#   'Embarked': 'S'},
#  {'PassengerId': '437',
#   'Ticket': 'W./C. 6608',
#   'Fare': '34375',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '438',
#   'Ticket': '29106',
#   'Fare': '18.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '439',
#   'Ticket': '19950',
#   'Fare': '263',
#   'Cabin': 'C23 C25 C27',
#   'Embarked': 'S'},
#  {'PassengerId': '440',
#   'Ticket': 'C.A. 18723',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '441',
#   'Ticket': 'F.C.C. 13529',
#   'Fare': '26.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '442',
#   'Ticket': '345769',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '443',
#   'Ticket': '347076',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '444',
#   'Ticket': '230434',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '445',
#   'Ticket': '65306',
#   'Fare': '8.1125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '446',
#   'Ticket': '33638',
#   'Fare': '81.8583',
#   'Cabin': 'A34',
#   'Embarked': 'S'},
#  {'PassengerId': '447',
#   'Ticket': '250644',
#   'Fare': '19.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '448',
#   'Ticket': '113794',
#   'Fare': '26.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '449',
#   'Ticket': '2666',
#   'Fare': '19.2583',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '450',
#   'Ticket': '113786',
#   'Fare': '30.5',
#   'Cabin': 'C104',
#   'Embarked': 'S'},
#  {'PassengerId': '451',
#   'Ticket': 'C.A. 34651',
#   'Fare': '27.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '452',
#   'Ticket': '65303',
#   'Fare': '19.9667',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '453',
#   'Ticket': '113051',
#   'Fare': '27.75',
#   'Cabin': 'C111',
#   'Embarked': 'C'},
#  {'PassengerId': '454',
#   'Ticket': '17453',
#   'Fare': '89.1042',
#   'Cabin': 'C92',
#   'Embarked': 'C'},
#  {'PassengerId': '455',
#   'Ticket': 'A/5 2817',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '456',
#   'Ticket': '349240',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '457',
#   'Ticket': '13509',
#   'Fare': '26.55',
#   'Cabin': 'E38',
#   'Embarked': 'S'},
#  {'PassengerId': '458',
#   'Ticket': '17464',
#   'Fare': '51.8625',
#   'Cabin': 'D21',
#   'Embarked': 'S'},
#  {'PassengerId': '459',
#   'Ticket': 'F.C.C. 13531',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '460',
#   'Ticket': '371060',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '461',
#   'Ticket': '19952',
#   'Fare': '26.55',
#   'Cabin': 'E12',
#   'Embarked': 'S'},
#  {'PassengerId': '462',
#   'Ticket': '364506',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '463',
#   'Ticket': '111320',
#   'Fare': '38.5',
#   'Cabin': 'E63',
#   'Embarked': 'S'},
#  {'PassengerId': '464',
#   'Ticket': '234360',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '465',
#   'Ticket': 'A/S 2816',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '466',
#   'Ticket': 'SOTON/O.Q. 3101306',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '467',
#   'Ticket': '239853',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '468',
#   'Ticket': '113792',
#   'Fare': '26.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '469',
#   'Ticket': '36209',
#   'Fare': '7725',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '470',
#   'Ticket': '2666',
#   'Fare': '19.2583',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '471',
#   'Ticket': '323592',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '472',
#   'Ticket': '315089',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '473',
#   'Ticket': 'C.A. 34651',
#   'Fare': '27.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '474',
#   'Ticket': 'SC/AH Basle 541',
#   'Fare': '13.7917',
#   'Cabin': 'D',
#   'Embarked': 'C'},
#  {'PassengerId': '475',
#   'Ticket': '7553',
# ...
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '734',
#   'Ticket': '28425',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '735',
#   'Ticket': '233639',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '736',
#   'Ticket': '54636',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '737',
#   'Ticket': 'W./C. 6608',
#   'Fare': '34375',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '738',
#   'Ticket': 'PC 17755',
#   'Fare': '512.3292',
#   'Cabin': 'B101',
#   'Embarked': 'C'},
#  {'PassengerId': '739',
#   'Ticket': '349201',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '740',
#   'Ticket': '349218',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '741',
#   'Ticket': '16988',
#   'Fare': '30',
#   'Cabin': 'D45',
#   'Embarked': 'S'},
#  {'PassengerId': '742',
#   'Ticket': '19877',
#   'Fare': '78.85',
#   'Cabin': 'C46',
#   'Embarked': 'S'},
#  {'PassengerId': '743',
#   'Ticket': 'PC 17608',
#   'Fare': '262375',
#   'Cabin': 'B57 B59 B63 B66',
#   'Embarked': 'C'},
#  {'PassengerId': '744',
#   'Ticket': '376566',
#   'Fare': '16.1',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '745',
#   'Ticket': 'STON/O 2. 3101288',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '746',
#   'Ticket': 'WE/P 5735',
#   'Fare': '71',
#   'Cabin': 'B22',
#   'Embarked': 'S'},
#  {'PassengerId': '747',
#   'Ticket': 'C.A. 2673',
#   'Fare': '20.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '748',
#   'Ticket': '250648',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '749',
#   'Ticket': '113773',
#   'Fare': '53.1',
#   'Cabin': 'D30',
#   'Embarked': 'S'},
#  {'PassengerId': '750',
#   'Ticket': '335097',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '751',
#   'Ticket': '29103',
#   'Fare': '23',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '752',
#   'Ticket': '392096',
#   'Fare': '12475',
#   'Cabin': 'E121',
#   'Embarked': 'S'},
#  {'PassengerId': '753',
#   'Ticket': '345780',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '754',
#   'Ticket': '349204',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '755',
#   'Ticket': '220845',
#   'Fare': '65',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '756',
#   'Ticket': '250649',
#   'Fare': '14.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '757',
#   'Ticket': '350042',
#   'Fare': '7.7958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '758',
#   'Ticket': '29108',
#   'Fare': '11.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '759',
#   'Ticket': '363294',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '760',
#   'Ticket': '110152',
#   'Fare': '86.5',
#   'Cabin': 'B77',
#   'Embarked': 'S'},
#  {'PassengerId': '761',
#   'Ticket': '358585',
#   'Fare': '14.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '762',
#   'Ticket': 'SOTON/O2 3101272',
#   'Fare': '7125',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '763',
#   'Ticket': '2663',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '764',
#   'Ticket': '113760',
#   'Fare': '120',
#   'Cabin': 'B96 B98',
#   'Embarked': 'S'},
#  {'PassengerId': '765',
#   'Ticket': '347074',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '766',
#   'Ticket': '13502',
#   'Fare': '77.9583',
#   'Cabin': 'D11',
#   'Embarked': 'S'},
#  {'PassengerId': '767',
#   'Ticket': '112379',
#   'Fare': '39.6',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '768',
#   'Ticket': '364850',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '769',
#   'Ticket': '371110',
#   'Fare': '24.15',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '770',
#   'Ticket': '8471',
#   'Fare': '8.3625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '771',
#   'Ticket': '345781',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '772',
#   'Ticket': '350047',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '773',
#   'Ticket': 'S.O./P.P. 3',
#   'Fare': '10.5',
#   'Cabin': 'E77',
#   'Embarked': 'S'},
#  {'PassengerId': '774',
#   'Ticket': '2674',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '775',
#   'Ticket': '29105',
#   'Fare': '23',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '776',
#   'Ticket': '347078',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '777',
#   'Ticket': '383121',
#   'Fare': '7.75',
#   'Cabin': 'F38',
#   'Embarked': 'Q'},
#  {'PassengerId': '778',
#   'Ticket': '364516',
#   'Fare': '12475',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '779',
#   'Ticket': '36865',
#   'Fare': '7.7375',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '780',
#   'Ticket': '24160',
#   'Fare': '211.3375',
#   'Cabin': 'B3',
#   'Embarked': 'S'},
#  {'PassengerId': '781',
#   'Ticket': '2687',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '782',
#   'Ticket': '17474',
#   'Fare': '57',
#   'Cabin': 'B20',
#   'Embarked': 'S'},
#  {'PassengerId': '783',
#   'Ticket': '113501',
#   'Fare': '30',
#   'Cabin': 'D6',
#   'Embarked': 'S'},
#  {'PassengerId': '784',
#   'Ticket': 'W./C. 6607',
#   'Fare': '23.45',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '785',
#   'Ticket': 'SOTON/O.Q. 3101312',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '786',
#   'Ticket': '374887',
#   'Fare': '7.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '787',
#   'Ticket': '3101265',
#   'Fare': '7.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '788',
#   'Ticket': '382652',
#   'Fare': '29125',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '789',
#   'Ticket': 'C.A. 2315',
#   'Fare': '20575',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '790',
#   'Ticket': 'PC 17593',
#   'Fare': '79.2',
#   'Cabin': 'B82 B84',
#   'Embarked': 'C'},
#  {'PassengerId': '791',
#   'Ticket': '12460',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '792',
#   'Ticket': '239865',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '793',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '794',
#   'Ticket': 'PC 17600',
#   'Fare': '30.6958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '795',
#   'Ticket': '349203',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '796',
#   'Ticket': '28213',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '797',
#   'Ticket': '17465',
#   'Fare': '25.9292',
#   'Cabin': 'D17',
#   'Embarked': 'S'},
#  {'PassengerId': '798',
#   'Ticket': '349244',
#   'Fare': '8.6833',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '799',
#   'Ticket': '2685',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '800',
#   'Ticket': '345773',
#   'Fare': '24.15',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '801',
#   'Ticket': '250647',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '802',
#   'Ticket': 'C.A. 31921',
#   'Fare': '26.25',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '803',
#   'Ticket': '113760',
#   'Fare': '120',
#   'Cabin': 'B96 B98',
#   'Embarked': 'S'},
#  {'PassengerId': '804',
#   'Ticket': '2625',
#   'Fare': '8.5167',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '805',
#   'Ticket': '347089',
#   'Fare': '6975',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '806',
#   'Ticket': '347063',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '807',
#   'Ticket': '112050',
#   'Fare': '0',
#   'Cabin': 'A36',
#   'Embarked': 'S'},
#  {'PassengerId': '808',
#   'Ticket': '347087',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '809',
#   'Ticket': '248723',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '810',
#   'Ticket': '113806',
#   'Fare': '53.1',
#   'Cabin': 'E8',
#   'Embarked': 'S'},
#  {'PassengerId': '811',
#   'Ticket': '3474',
#   'Fare': '7.8875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '812',
#   'Ticket': 'A/4 48871',
#   'Fare': '24.15',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '813',
#   'Ticket': '28206',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '814',
#   'Ticket': '347082',
#   'Fare': '31275',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '815',
#   'Ticket': '364499',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '816',
#   'Ticket': '112058',
#   'Fare': '0',
#   'Cabin': 'B102',
#   'Embarked': 'S'},
#  {'PassengerId': '817',
#   'Ticket': 'STON/O2. 3101290',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '818',
#   'Ticket': 'S.C./PARIS 2079',
#   'Fare': '37.0042',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '819',
#   'Ticket': 'C 7075',
#   'Fare': '6.45',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '820',
#   'Ticket': '347088',
#   'Fare': '27.9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '821',
#   'Ticket': '12749',
#   'Fare': '93.5',
#   'Cabin': 'B69',
#   'Embarked': 'S'},
#  {'PassengerId': '822',
#   'Ticket': '315098',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '823',
#   'Ticket': '19972',
#   'Fare': '0',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '824',
#   'Ticket': '392096',
#   'Fare': '12475',
#   'Cabin': 'E121',
#   'Embarked': 'S'},
#  {'PassengerId': '825',
#   'Ticket': '3101295',
#   'Fare': '39.6875',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '826',
#   'Ticket': '368323',
#   'Fare': '6.95',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '827',
#   'Ticket': '1601',
#   'Fare': '56.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '828',
#   'Ticket': 'S.C./PARIS 2079',
#   'Fare': '37.0042',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '829',
#   'Ticket': '367228',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '830',
#   'Ticket': '113572',
#   'Fare': '80',
#   'Cabin': 'B28',
#   'Embarked': ''},
#  {'PassengerId': '831',
#   'Ticket': '2659',
#   'Fare': '14.4542',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '832',
#   'Ticket': '29106',
#   'Fare': '18.75',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '833',
#   'Ticket': '2671',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '834',
#   'Ticket': '347468',
#   'Fare': '7.8542',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '835',
#   'Ticket': '2223',
#   'Fare': '8.3',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '836',
#   'Ticket': 'PC 17756',
#   'Fare': '83.1583',
#   'Cabin': 'E49',
#   'Embarked': 'C'},
#  {'PassengerId': '837',
#   'Ticket': '315097',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '838',
#   'Ticket': '392092',
#   'Fare': '8.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '839',
#   'Ticket': '1601',
#   'Fare': '56.4958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '840',
#   'Ticket': '11774',
#   'Fare': '29.7',
#   'Cabin': 'C47',
#   'Embarked': 'C'},
#  {'PassengerId': '841',
#   'Ticket': 'SOTON/O2 3101287',
#   'Fare': '7925',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '842',
#   'Ticket': 'S.O./P.P. 3',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '843',
#   'Ticket': '113798',
#   'Fare': '31',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '844',
#   'Ticket': '2683',
#   'Fare': '6.4375',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '845',
#   'Ticket': '315090',
#   'Fare': '8.6625',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '846',
#   'Ticket': 'C.A. 5547',
#   'Fare': '7.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '847',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '848',
#   'Ticket': '349213',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '849',
#   'Ticket': '248727',
#   'Fare': '33',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '850',
#   'Ticket': '17453',
#   'Fare': '89.1042',
#   'Cabin': 'C92',
#   'Embarked': 'C'},
#  {'PassengerId': '851',
#   'Ticket': '347082',
#   'Fare': '31275',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '852',
#   'Ticket': '347060',
#   'Fare': '7775',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '853',
#   'Ticket': '2678',
#   'Fare': '15.2458',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '854',
#   'Ticket': 'PC 17592',
#   'Fare': '39.4',
#   'Cabin': 'D28',
#   'Embarked': 'S'},
#  {'PassengerId': '855',
#   'Ticket': '244252',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '856',
#   'Ticket': '392091',
#   'Fare': '9.35',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '857',
#   'Ticket': '36928',
#   'Fare': '164.8667',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '858',
#   'Ticket': '113055',
#   'Fare': '26.55',
#   'Cabin': 'E17',
#   'Embarked': 'S'},
#  {'PassengerId': '859',
#   'Ticket': '2666',
#   'Fare': '19.2583',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '860',
#   'Ticket': '2629',
#   'Fare': '7.2292',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '861',
#   'Ticket': '350026',
#   'Fare': '14.1083',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '862',
#   'Ticket': '28134',
#   'Fare': '11.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '863',
#   'Ticket': '17466',
#   'Fare': '25.9292',
#   'Cabin': 'D17',
#   'Embarked': 'S'},
#  {'PassengerId': '864',
#   'Ticket': 'CA. 2343',
#   'Fare': '69.55',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '865',
#   'Ticket': '233866',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '866',
#   'Ticket': '236852',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '867',
#   'Ticket': 'SC/PARIS 2149',
#   'Fare': '13.8583',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '868',
#   'Ticket': 'PC 17590',
#   'Fare': '50.4958',
#   'Cabin': 'A24',
#   'Embarked': 'S'},
#  {'PassengerId': '869',
#   'Ticket': '345777',
#   'Fare': '9.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '870',
#   'Ticket': '347742',
#   'Fare': '11.1333',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '871',
#   'Ticket': '349248',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '872',
#   'Ticket': '11751',
#   'Fare': '52.5542',
#   'Cabin': 'D35',
#   'Embarked': 'S'},
#  {'PassengerId': '873',
#   'Ticket': '695',
#   'Fare': '5',
#   'Cabin': 'B51 B53 B55',
#   'Embarked': 'S'},
#  {'PassengerId': '874',
#   'Ticket': '345765',
#   'Fare': '9',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '875',
#   'Ticket': 'P/PP 3381',
#   'Fare': '24',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '876',
#   'Ticket': '2667',
#   'Fare': '7225',
#   'Cabin': '',
#   'Embarked': 'C'},
#  {'PassengerId': '877',
#   'Ticket': '7534',
#   'Fare': '9.8458',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '878',
#   'Ticket': '349212',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '879',
#   'Ticket': '349217',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '880',
#   'Ticket': '11767',
#   'Fare': '83.1583',
#   'Cabin': 'C50',
#   'Embarked': 'C'},
#  {'PassengerId': '881',
#   'Ticket': '230433',
#   'Fare': '26',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '882',
#   'Ticket': '349257',
#   'Fare': '7.8958',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '883',
#   'Ticket': '7552',
#   'Fare': '10.5167',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '884',
#   'Ticket': 'C.A./SOTON 34068',
#   'Fare': '10.5',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '885',
#   'Ticket': 'SOTON/OQ 392076',
#   'Fare': '7.05',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '886',
#   'Ticket': '382652',
#   'Fare': '29125',
#   'Cabin': '',
#   'Embarked': 'Q'},
#  {'PassengerId': '887',
#   'Ticket': '211536',
#   'Fare': '13',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '888',
#   'Ticket': '112053',
#   'Fare': '30',
#   'Cabin': 'B42',
#   'Embarked': 'S'},
#  {'PassengerId': '889',
#   'Ticket': 'W./C. 6607',
#   'Fare': '23.45',
#   'Cabin': '',
#   'Embarked': 'S'},
#  {'PassengerId': '890',
#   'Ticket': '111369',
#   'Fare': '30',
#   'Cabin': 'C148',
#   'Embarked': 'C'},
#  {'PassengerId': '891',
#   'Ticket': '370376',
#   'Fare': '7.75',
#   'Cabin': '',
#   'Embarked': 'Q'}]

# %% [markdown]
# ### TAREFA 02
# 1. Cria a tabela passageiros.
# 2. PassenderId deve ser a chave primária.

# %%
passageiros = importar_csv('passageiros.csv')
# Out:
# O conjunto de dados tem 891 registros.

# %% [markdown]
# ### 2.2. Criando o banco de dados
# Para manipular um banco SQLite com Python, temos que utilizar uma biblioteca específica.

# %%
import sqlite3
conn = sqlite3.connect('titanic1.db')

# %% [markdown]
# O comando acima cria o arquivo [titanic.db](titanic.db), que armazará nossos dados.

# %% [markdown]
# ### 2.3. Criando as tabelas
# Neste momento, temos do dados e o banco SQLlite. Então é hora de começar à usar comandos SQL para criar as tabelas que armazenarão nossos dados dentro do banco.
#
# No SQLlite, precisamos primeiro criar uma conexão e um cursor para executar nossos comandos no banco. Para facilicar, o código abaixo facilita este processo. Você só precisa passar seu comando SQL para a função.

# %%
def executa(comando):
    cursor = conn.cursor()
    cursor.execute(comando)
    cursor.close()

# %% [markdown]
# Não execute o comando abaixo, pois ele dá um erro. É só um exemplo

# %%
executa('CREATE TABLE passageiros2 (PassengerId INTEGER PRIMARY KEY, Survived INTEGER, Pclass INTEGER, Name VARCHAR(100), Sex VARCHAR(16), Age FLOAT(5), Sibsp INTEGER, Parch INTEGER )')

# %% [markdown]
# ### TAREFA 03
# 1. Cria a tabela passagens.
# 2. PassenderId deve ser a chave primária.

# %%
executa('CREATE TABLE passagens1(PassengerId INTEGER PRIMARY KEY, Ticket INTEGER, Fare FLOAT(5), Cabin INTEGER, Embarked VARCHAR(4))')

# %% [markdown]
# **Atenção:** Caso você tente executar os comandos de criação de tabelas mais de uma vez, perceberá um erro de operação informando que a tabela já existe.
#
# Vamos verificar se as tabelas foram realmente criadas? Abra o terminal e na pasta atual digite:
# ```
# $ sqlite3.exe titanic.db ".tables"
# ```
# O terminal deve retornar com as tabelas existentes em seu banco [titanic.db](titanic.db). Neste casos, *passageiros* e *passagens*. Lembre-se que neste momento, não temos nenhum dado inseridos nas tabelas.
#
# Caso queira verifcar mais algumas informações das tabelas criadas, pode executar esta outra instrução:
# ```
# $ sqlite3.exe titanic.db "PRAGMA table_info(passageiros)"
# ```

# %% [markdown]
# ### TAREFA 05
# 1. Pelo terminal, verifique mais informações da tabela passagens.

# %% [markdown]
# ### 2.4. Inserindo dados nas tabelas
# Usando o comando INSERT INTO, vamos popular as nossas tabelas. O processo é simples, percorremos as listas de dicionários, montamos nosso comando INSERT INT e executamos - uma a uma. Para a tabela passageiros:

# %%
for p in passageiros:
    p['Name'] = p['Name'].replace('"', "'")
    inserir_passageiro = ("""
    INSERT INTO passageiros2(PassengerId, Survived, Pclass, Name, Sex, Age, Sibsp, Parch)
    VALUES (%s, "%s", "%s", "%s", "%s", "%s", "%s", "%s")""") % (p['PassengerId'], p['Survived'], p['Pclass'],
                                                                 p['Name'], p['Sex'], p['Age'], p['SibSp'],
                                                                 p['Parch'])
    executa(inserir_passageiro)

# %% [markdown]
# ### TAREFA 06
# 1. Insira os dados de passagens dentro da tabela passagens

# %% [markdown]
# PassengerId: Id do passageiro
# - Ticket: número do ticket de embarque
# - Fare: valor pago pelo ticket.
# - Cabin: cabine do passageiro.
# - Embarked: porto de embarque do passageiro. C = Cherbourg, Q = Queenstown e S = Southampton

# %%
for pas in passagens:
    inserir_dados = ("""
    INSERT INTO passagens1(PassengerId, Ticket, Fare, Cabin, Embarked)
    VALUES (%s, "%s", "%s", "%s", "%s")""") % (pas['PassengerId'], pas['Ticket'], pas['Fare'],
                                                                 pas['Cabin'], pas['Embarked']
                                              )
    executa(inserir_dados)

# %% [markdown]
# ### 2.5. Executando consultas
# Agora que os dados estão inseridos no arquivo banco SQLite, vamos executar alguns consultas. Vamos começar fazendo uma seleção de todas as colunas das tabelas.
#
# O comando SELECT retorna dados, deste modo, precisamos fazer alguma alteração na função executa. utilize o *executa_consulta()*.

# %%
def executa_consulta(consulta):
    cursor = conn.cursor()
    cursor.execute(consulta)
    for linha in cursor.fetchall():
        print(linha)
    
    cursor.close()

# %% [markdown]
# Testando nosso código. Repare que o comando LIMIT foi utilizado para limitar a quantidade de linhas.

# %%
executa_consulta('SELECT*FROM passageiros2 LIMIT 10')
# Out:
# (1, 0, 3, 'Braund, Mr. Owen Harris', 'male', 22.0, 1, 0)
# (2, 1, 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', 38.0, 1, 0)
# (3, 1, 3, 'Heikkinen, Miss. Laina', 'female', 26.0, 0, 0)
# (4, 1, 1, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', 35.0, 1, 0)
# (5, 0, 3, 'Allen, Mr. William Henry', 'male', 35.0, 0, 0)
# (6, 0, 3, 'Moran, Mr. James', 'male', '', 0, 0)
# (7, 0, 1, 'McCarthy, Mr. Timothy J', 'male', 54.0, 0, 0)
# (8, 0, 3, 'Palsson, Master. Gosta Leonard', 'male', 2.0, 3, 1)
# (9, 1, 3, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'female', 27.0, 0, 2)
# (10, 1, 2, 'Nasser, Mrs. Nicholas (Adele Achem)', 'female', 14.0, 1, 0)

# %% [markdown]
# ### TAREFA 07
# 1. Verifique quantos tipos de classe (PClass) existem na tabela passageiros.

# %%
executa_consulta('SELECT DISTINCT(Pclass) FROM passageiros2')
# Out:
# (3,)
# (1,)
# (2,)

# %% [markdown]
# ### TAREFA 08
# 1. Selenione os passageiros do sexo masculino (Sex) e que estejam na segunda classe (PClass).
#
# **DICA**: Use a cláusula WHERE e uma condicional (AND ou OR).

# %%
executa_consulta('SELECT * FROM passageiros2 WHERE Sex = "male" AND Pclass = 2')
# Out:
# (18, 1, 2, 'Williams, Mr. Charles Eugene', 'male', '', 0, 0)
# (21, 0, 2, 'Fynney, Mr. Joseph J', 'male', 35.0, 0, 0)
# (22, 1, 2, 'Beesley, Mr. Lawrence', 'male', 34.0, 0, 0)
# (34, 0, 2, 'Wheadon, Mr. Edward H', 'male', 66.0, 0, 0)
# (71, 0, 2, 'Jenkin, Mr. Stephen Curnow', 'male', 32.0, 0, 0)
# (73, 0, 2, 'Hood, Mr. Ambrose Jr', 'male', 21.0, 0, 0)
# (79, 1, 2, 'Caldwell, Master. Alden Gates', 'male', 0.83, 0, 2)
# (100, 0, 2, 'Kantor, Mr. Sinai', 'male', 34.0, 1, 0)
# (118, 0, 2, 'Turpin, Mr. William John Robert', 'male', 29.0, 1, 0)
# (121, 0, 2, 'Hickman, Mr. Stanley George', 'male', 21.0, 2, 0)
# (123, 0, 2, 'Nasser, Mr. Nicholas', 'male', 32.5, 1, 0)
# (135, 0, 2, 'Sobey, Mr. Samuel James Hayden', 'male', 25.0, 0, 0)
# (136, 0, 2, 'Richard, Mr. Emile', 'male', 23.0, 0, 0)
# (145, 0, 2, 'Andrew, Mr. Edgardo Samuel', 'male', 18.0, 0, 0)
# (146, 0, 2, 'Nicholls, Mr. Joseph Charles', 'male', 19.0, 1, 1)
# (149, 0, 2, "Navratil, Mr. Michel ('Louis M Hoffman')", 'male', 36.5, 0, 2)
# (150, 0, 2, 'Byles, Rev. Thomas Roussel Davids', 'male', 42.0, 0, 0)
# (151, 0, 2, 'Bateman, Rev. Robert James', 'male', 51.0, 0, 0)
# (179, 0, 2, 'Hale, Mr. Reginald', 'male', 30.0, 0, 0)
# (182, 0, 2, 'Pernot, Mr. Rene', 'male', '', 0, 0)
# (184, 1, 2, 'Becker, Master. Richard F', 'male', 1.0, 2, 1)
# (192, 0, 2, 'Carbines, Mr. William', 'male', 19.0, 0, 0)
# (194, 1, 2, 'Navratil, Master. Michel M', 'male', 3.0, 1, 1)
# (214, 0, 2, 'Givard, Mr. Hans Kristensen', 'male', 30.0, 0, 0)
# (218, 0, 2, 'Jacobsohn, Mr. Sidney Samuel', 'male', 42.0, 1, 0)
# (220, 0, 2, 'Harris, Mr. Walter', 'male', 30.0, 0, 0)
# (222, 0, 2, 'Bracken, Mr. James H', 'male', 27.0, 0, 0)
# (227, 1, 2, 'Mellors, Mr. William John', 'male', 19.0, 0, 0)
# (229, 0, 2, 'Fahlstrom, Mr. Arne Jonas', 'male', 18.0, 0, 0)
# (233, 0, 2, 'Sjostedt, Mr. Ernst Adolf', 'male', 59.0, 0, 0)
# (235, 0, 2, 'Leyson, Mr. Robert William Norman', 'male', 24.0, 0, 0)
# (237, 0, 2, 'Hold, Mr. Stephen', 'male', 44.0, 1, 0)
# (239, 0, 2, 'Pengelly, Mr. Frederick William', 'male', 19.0, 0, 0)
# (240, 0, 2, 'Hunt, Mr. George Henry', 'male', 33.0, 0, 0)
# (243, 0, 2, 'Coleridge, Mr. Reginald Charles', 'male', 29.0, 0, 0)
# (250, 0, 2, 'Carter, Rev. Ernest Courtenay', 'male', 54.0, 1, 0)
# (266, 0, 2, 'Reeves, Mr. David', 'male', 36.0, 0, 0)
# (278, 0, 2, "Parkes, Mr. Francis 'Frank'", 'male', '', 0, 0)
# (289, 1, 2, 'Hosono, Mr. Masabumi', 'male', 42.0, 0, 0)
# (293, 0, 2, 'Levy, Mr. Rene Jacques', 'male', 36.0, 0, 0)
# (309, 0, 2, 'Abelson, Mr. Samuel', 'male', 30.0, 1, 0)
# (315, 0, 2, 'Hart, Mr. Benjamin', 'male', 43.0, 1, 1)
# (318, 0, 2, 'Moraweck, Dr. Ernest', 'male', 54.0, 0, 0)
# (341, 1, 2, 'Navratil, Master. Edmond Roger', 'male', 2.0, 1, 1)
# (343, 0, 2, 'Collander, Mr. Erik Gustaf', 'male', 28.0, 0, 0)
# (344, 0, 2, 'Sedgwick, Mr. Charles Frederick Waddington', 'male', 25.0, 0, 0)
# (345, 0, 2, 'Fox, Mr. Stanley Hubert', 'male', 36.0, 0, 0)
# (362, 0, 2, 'del Carlo, Mr. Sebastiano', 'male', 29.0, 1, 0)
# (386, 0, 2, 'Davies, Mr. Charles Henry', 'male', 18.0, 0, 0)
# (398, 0, 2, 'McKane, Mr. Peter David', 'male', 46.0, 0, 0)
# (399, 0, 2, 'Pain, Dr. Alfred', 'male', 23.0, 0, 0)
# (406, 0, 2, 'Gale, Mr. Shadrach', 'male', 34.0, 1, 0)
# (408, 1, 2, 'Richards, Master. William Rowe', 'male', 3.0, 1, 1)
# (414, 0, 2, 'Cunningham, Mr. Alfred Fleming', 'male', '', 0, 0)
# (419, 0, 2, 'Matthews, Mr. William John', 'male', 30.0, 0, 0)
# (440, 0, 2, 'Kvillner, Mr. Johan Henrik Johannesson', 'male', 31.0, 0, 0)
# (451, 0, 2, 'West, Mr. Edwy Arthur', 'male', 36.0, 1, 2)
# (464, 0, 2, 'Milling, Mr. Jacob Christian', 'male', 48.0, 0, 0)
# (467, 0, 2, 'Campbell, Mr. William', 'male', '', 0, 0)
# (477, 0, 2, 'Renouf, Mr. Peter Henry', 'male', 34.0, 1, 0)
# (482, 0, 2, "Frost, Mr. Anthony Wood 'Archie'", 'male', '', 0, 0)
# (530, 0, 2, 'Hocking, Mr. Richard George', 'male', 23.0, 2, 1)
# (544, 1, 2, 'Beane, Mr. Edward', 'male', 32.0, 1, 0)
# (548, 1, 2, 'Padro y Manent, Mr. Julian', 'male', '', 0, 0)
# (550, 1, 2, 'Davies, Master. John Morgan Jr', 'male', 8.0, 1, 1)
# (552, 0, 2, 'Sharp, Mr. Percival James R', 'male', 27.0, 0, 0)
# (563, 0, 2, 'Norman, Mr. Robert Douglas', 'male', 28.0, 0, 0)
# (571, 1, 2, 'Harris, Mr. George', 'male', 62.0, 0, 0)
# (583, 0, 2, 'Downton, Mr. William James', 'male', 54.0, 0, 0)
# (587, 0, 2, 'Jarvis, Mr. John Denzil', 'male', 47.0, 0, 0)
# (595, 0, 2, 'Chapman, Mr. John Henry', 'male', 37.0, 1, 0)
# (620, 0, 2, 'Gavey, Mr. Lawrence', 'male', 26.0, 0, 0)
# (627, 0, 2, 'Kirkland, Rev. Charles Leonard', 'male', 57.0, 0, 0)
# (638, 0, 2, 'Collyer, Mr. Harvey', 'male', 31.0, 1, 1)
# (656, 0, 2, 'Hickman, Mr. Leonard Mark', 'male', 24.0, 2, 0)
# (659, 0, 2, 'Eitemiller, Mr. George Floyd', 'male', 23.0, 0, 0)
# (666, 0, 2, 'Hickman, Mr. Lewis', 'male', 32.0, 2, 0)
# (667, 0, 2, 'Butler, Mr. Reginald Fenton', 'male', 25.0, 0, 0)
# (673, 0, 2, 'Mitchell, Mr. Henry Michael', 'male', 70.0, 0, 0)
# (674, 1, 2, 'Wilhelms, Mr. Charles', 'male', 31.0, 0, 0)
# (675, 0, 2, 'Watson, Mr. Ennis Hastings', 'male', '', 0, 0)
# (685, 0, 2, 'Brown, Mr. Thomas William Solomon', 'male', 60.0, 1, 1)
# (686, 0, 2, 'Laroche, Mr. Joseph Philippe Lemercier', 'male', 25.0, 1, 2)
# (696, 0, 2, 'Chapman, Mr. Charles Henry', 'male', 52.0, 0, 0)
# (706, 0, 2, "Morley, Mr. Henry Samuel ('Mr Henry Marshall')", 'male', 39.0, 0, 0)
# (715, 0, 2, 'Greenberg, Mr. Samuel', 'male', 52.0, 0, 0)
# (723, 0, 2, 'Gillespie, Mr. William Henry', 'male', 34.0, 0, 0)
# (724, 0, 2, 'Hodges, Mr. Henry Price', 'male', 50.0, 0, 0)
# (729, 0, 2, 'Bryhl, Mr. Kurt Arnold Gottfrid', 'male', 25.0, 1, 0)
# (733, 0, 2, 'Knight, Mr. Robert J', 'male', '', 0, 0)
# (734, 0, 2, 'Berriman, Mr. William John', 'male', 23.0, 0, 0)
# (735, 0, 2, 'Troupiansky, Mr. Moses Aaron', 'male', 23.0, 0, 0)
# (756, 1, 2, 'Hamalainen, Master. Viljo', 'male', 0.67, 1, 1)
# (758, 0, 2, 'Bailey, Mr. Percy Andrew', 'male', 18.0, 0, 0)
# (792, 0, 2, 'Gaskell, Mr. Alfred', 'male', 16.0, 0, 0)
# (796, 0, 2, 'Otter, Mr. Richard', 'male', 39.0, 0, 0)
# (801, 0, 2, 'Ponesell, Mr. Martin', 'male', 34.0, 0, 0)
# (809, 0, 2, 'Meyer, Mr. August', 'male', 39.0, 0, 0)
# (813, 0, 2, 'Slemen, Mr. Richard James', 'male', 35.0, 0, 0)
# (818, 0, 2, 'Mallet, Mr. Albert', 'male', 31.0, 1, 1)
# (828, 1, 2, 'Mallet, Master. Andre', 'male', 1.0, 0, 2)
# (832, 1, 2, 'Richards, Master. George Sibley', 'male', 0.83, 1, 1)
# (842, 0, 2, 'Mudd, Mr. Thomas Charles', 'male', 16.0, 0, 0)
# (849, 0, 2, 'Harper, Rev. John', 'male', 28.0, 0, 1)
# (862, 0, 2, 'Giles, Mr. Frederick Edward', 'male', 21.0, 1, 0)
# (865, 0, 2, 'Gill, Mr. John William', 'male', 24.0, 0, 0)
# (884, 0, 2, 'Banfield, Mr. Frederick James', 'male', 28.0, 0, 0)
# (887, 0, 2, 'Montvila, Rev. Juozas', 'male', 27.0, 0, 0)

# %% [markdown]
# ### TAREFA 09
# 1. Conte quantos passageiros existem por sexo.
#
# **DICA**: Use GROUP BY e COUNT().

# %%
executa_consulta('SELECT COUNT(*), Sex FROM passageiros2 GROUP BY Sex')
# Out:
# (314, 'female')
# (577, 'male')

# %% [markdown]
# ### TAREFA 10
# 1. Verifique o valor médio das passagens em cada porto de embarque
#
# **DICA**: Use GROUP BY e AVG(). A presença de valores missing pode apresentar alguns resultados estranhos.

# %%
executa_consulta('SELECT AVG(FARE), Embarked FROM passagens1 WHERE Embarked = "S" OR Embarked = "C" OR Embarked = "Q" GROUP BY Embarked')
# Out:
# (12709.34566190476, 'C')
# (2002.8429129870128, 'Q')
# (2015.3069857142902, 'S')

# %% [markdown]
# ### TAREFA 11
# 1. Selecione o nome (Name), sexo(Sex) e tarifa(Fare) paga de 5 passageiros
# 2. Utilize as tabelas passageiros e passagens.
#
# **DICA**: Use JOIN.

# %%
executa_consulta('SELECT Name, Sex, Fare FROM passageiros2 as p JOIN passagens1 as pa ON p.PassengerId = pa.PassengerId LIMIT 5')
# Out:
# ('Braund, Mr. Owen Harris', 'male', 7.25)
# ('Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', 71.2833)
# ('Heikkinen, Miss. Laina', 'female', 7925.0)
# ('Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', 53.1)
# ('Allen, Mr. William Henry', 'male', 8.05)

# %% [markdown]
# ### TAREFA 12
# 1. Selecione o valor máximo (Fare) das passagens por classe.

# %%
executa_consulta('SELECT Pclass, MAX(Fare) FROM passageiros2 as p JOIN passagens1 as pa ON p.PassengerId = pa.PassengerId GROUP BY Pclass')
# Out:
# (1, 262375.0)
# (2, 12875.0)
# (3, 34375.0)

# %% [markdown]
# ### TAREFA 13
# 1. Descubra quantas pessoas embarcaram por porto
# 2. Agrupando por sexo.

# %%
executa_consulta('SELECT Embarked, COUNT(*), Sex FROM passageiros2 as p JOIN passagens1 as pa ON p.PassengerId = pa.PassengerId GROUP BY Embarked, Sex')
# Out:
# ('', 2, 'female')
# ('C', 73, 'female')
# ('C', 95, 'male')
# ('Q', 36, 'female')
# ('Q', 41, 'male')
# ('S', 203, 'female')
# ('S', 441, 'male')

# %% [markdown]
# ## 3. Conclusão
#
# A quantidade de consultas e a lista de comandos SQL é enorme. A interação foi somente relembrar alguns comandos básicos para que você se sinta confortável para explorar qualquer banco de dados SQL que você encontrar.

# %%
http://localhost:8889/nbconvert/html/Downloads/Awari/EXERCICIO%207/Projeto%20-%20Python%20com%20SQLite.ipynb?download=false

# %% [markdown]
# ### Awari -  <a href="https://awari.com.br/"> awari.com.br</a>
